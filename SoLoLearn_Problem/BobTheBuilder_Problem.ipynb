# %%
from IPython.display import Image
Image("BobTheBuilder_Given1.png")

# %%
from IPython.display import Image
Image("BobTheBuilder_Given2.png")

# %%
n = int(input())
X = []
for i in range(n):
    X.append([float(x) for x in input().split()])
y = [int(x) for x in input().split()]
datapoint = [float(x) for x in input().split()]

#Above 5 lines are given or the Input Format
# Note: input() is given in SoloLearn
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-53c5b326dce7> in <module>
# ----> 1 n = int(input())
#       2 X = []
#       3 for i in range(n):
#       4     X.append([float(x) for x in input().split()])
#       5 y = [int(x) for x in input().split()]
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
# ...

# %%
#Below are my answers
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X,y)

#print(X)
#print(y)
#print(datapoint)

#The output is an integer so convert your answer to integer.
print(int(model.predict([datapoint])))
